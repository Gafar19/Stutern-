# %%
import sqlite3
conn = sqlite3.connect("attr_data.db")
print("database created successfully")
print(type(conn))
# Out:
# database created successfully
# <class 'sqlite3.Connection'>

# %%
cursor = conn.cursor()
print("cursor created successfully /n", type(cursor))
# Out:
# cursor created successfully /n <class 'sqlite3.Cursor'>

# %%
cursor.execute("""
        CREATE TABLE IF NOT EXISTS ATTRITION ( 
            'id', 'Age', 'Attrition', 'BusinessTravel', 
                                               'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField','EmployeeCount','EmployeeNumber',
                                               'EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement','JobLevel','JobRole','JobSatisfaction',
                                               'MaritalStatus','MonthlyIncome','MonthlyRate','NumCompaniesWorked','Over18','OverTime','PercentSalaryHike','PerformanceRating',
                                               'RelationshipSatisfaction','StandardHours','StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance',
                                               'YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager'

        );
""")
print("Table created successfully")
# Out:
# Table created successfully

# %%
conn.commit()

# %%
import sqlite3
conn = sqlite3.connect("attr_data.db")

# %%
import pandas as pd

# %%
sql_query = pd.read_sql_query('''SELECT * FROM attrition_records''', conn)

# %%
df = pd.DataFrame(sql_query, columns= ['id', 'Age', 'Attrition', 'BusinessTravel', 
                                               'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField','EmployeeCount','EmployeeNumber',
                                               'EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement','JobLevel','JobRole','JobSatisfaction',
                                               'MaritalStatus','MonthlyIncome','MonthlyRate','NumCompaniesWorked','Over18','OverTime','PercentSalaryHike','PerformanceRating',
                                               'RelationshipSatisfaction','StandardHours','StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance',
                                               'YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager'])

# %%
#convert to csv
df.to_csv('result.csv', index=False)
df
# Out:
#         id  Age Attrition     BusinessTravel  DailyRate  \
# 0        1   41       Yes      Travel_Rarely       1102
# 1        2   49        No  Travel_Frequently        279
# 2        3   37       Yes      Travel_Rarely       1373
# 3        4   33        No  Travel_Frequently       1392
# 4        5   27        No      Travel_Rarely        591
# ...    ...  ...       ...                ...        ...
# 1465  1466   36        No  Travel_Frequently        884
# 1466  1467   39        No      Travel_Rarely        613
# 1467  1468   27        No      Travel_Rarely        155
# 1468  1469   49        No  Travel_Frequently       1023
# 1469  1470   34        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# ...

# %%
df.describe()
# Out:
#                 id          Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean    735.500000    36.923810   802.485714          9.192517     2.912925
# std     424.496761     9.135373   403.509100          8.106864     1.024165
# min       1.000000    18.000000   102.000000          1.000000     1.000000
# 25%     368.250000    30.000000   465.000000          2.000000     2.000000
# 50%     735.500000    36.000000   802.000000          7.000000     3.000000
# 75%    1102.750000    43.000000  1157.000000         14.000000     4.000000
# max    1470.000000    60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# ...

# %%
#What do you think are the 3 factors behind employee attrition?
sns.scatterplot(x='Age', y='MonthlyIncome', hue='Attrition', style='Education', palette='bright', data=df)
plt.show()

# %% [markdown]
# Age, monthly income and education are the three (3) factors I believed is affecting employee's attrition

# %%
#Relatinship between Education and Monthly income
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.scatterplot(x=df['Education'], y=df['MonthlyIncome'])
plt.show()
df['Education'].corr(df['MonthlyIncome'])
# Out:
# 0.09496067704188885

# %% [markdown]
# The correlation coefficient of 0.09 indicates no linear association or correlation between education and monthly income. Additionally, the scatter plot above shows no corellation between education and monthly income

# %%
# The effect of age on attrition?
sns.boxplot(x='Attrition', y='Age', data=df)
plt.show()

# %% [markdown]
# From the figure above, age has minimal effect in the employees' attrition.

# %%
# Is Income the main factor in employee attrition?

sns.boxplot(x='Attrition', y='MonthlyIncome', data=df)
plt.show()

# %% [markdown]
# The result above shows that income is a major factor determining employees' attrition

# %%
# How does work-life balance impact the overall attrition rate?
sns.boxplot(x=df['Attrition'], y=df['WorkLifeBalance'])
plt.show()

# %% [markdown]
# From the figure above, work life balance does not have any significant effect on the attrition level of employee
